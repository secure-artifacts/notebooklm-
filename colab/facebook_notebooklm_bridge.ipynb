# %% [markdown]
# # NotebookLM Facebook 临时媒体桥
#
# 由扩展自动填入会话并运行。媒体会直接上传到 NotebookLM 提供的一次性 Google 上传会话，不会保存到 Google Drive。

# %%
# 该单元格由 NotebookLM 扩展在临时 playground 中替换并运行。
print('等待 NotebookLM 扩展启动临时桥……')
