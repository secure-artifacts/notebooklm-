# %% [markdown]
# # NotebookLM Colab bridge probe
#
# 此探针只验证临时 Colab 运行时和结构化输出协议，不下载媒体、不访问 Google Drive，也不会启动公网服务。

# %%
import json, platform, sys, uuid

event = {
    "event_id": uuid.uuid4().hex,
    "type": "ready",
    "protocol": 1,
    "python": sys.version.split()[0],
    "platform": platform.system(),
}
print("NLM_BRIDGE:" + json.dumps(event, ensure_ascii=False, separators=(",", ":")))
